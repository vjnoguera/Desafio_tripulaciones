# %%
import pandas as pd
import numpy as np
import pickle
from flask import Flask, request, jsonify,render_template
# from sqlalchemy import create_engine
# import sqlite3
# import joblib
import cohere
# import cv2
# import matplotlib.pyplot as plt
# from prodiapy import Prodia
import requests
from io import BytesIO

# %%
from pymongo import MongoClient
# import pandas as pd

# Definir la función para descargar la colección desde MongoDB
def download_collection_from_mongodb(uri, db_name, collection_name):
    # Conectar a MongoDB
    client = MongoClient(uri)
    try:
        # Seleccionar la base de datos y la colección
        db = client[db_name]
        collection = db[collection_name]

        # Descargar los datos de la colección
        data = list(collection.find())

        # Convertir los datos a un DataFrame de pandas
        df = pd.DataFrame(data)
    finally:
        # Cerrar la conexión
        client.close()
    
    return df

# Datos de conexión a MongoDB
uri = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"  # Cambia la URL según sea necesario
db_name = "Samoo"  # Cambia 'nombre_de_la_base_de_datos' por el nombre de tu base de datos
collection_name = "users"  # Cambia 'nombre_de_la_coleccion' por el nombre de tu colección

# Descargar la colección y convertirla en un DataFrame
dff_users = download_collection_from_mongodb(uri, db_name, collection_name)

# Mostrar el DataFrame
# dff_users

co = cohere.Client(api_key="l*******************")
question = "cuantos asistentes omnivoro hay?"
prompt = f"""En base al siguiente Dataframe {dff_users}, quiero que respondas a la pregunta registrada en {question}. En la respuesta,
 intenta ser los más conciso posible, y pon solo texto normal, nada parecido a "\n" o similar.Al revisar la información del Dataframe, necesito 
  que lo revises entero, contando cada celda para asegurarte de darme la respuesta correcta. Por ejemplo; hay 99 veganos, pero sigues dándome
  como respuesta que hay 5, eso es erroneo. """
response = co.generate(
                    model = "command-nightly",
                    prompt = prompt,
                    max_tokens = 200,
                    temperature = 0.01,
                    k=0,
                    p = 0.75,
                    stop_sequences = [],
                    return_likelihoods = "NONE"
                    )

nav = response.generations[0].text
nav
# Out:
# 'Hay 1 asistente omnivoro.'

# %%
dff_users.T
# Out:
#                                                     0    \
# _id                                                   4
# name                                               Luis
# surname                                           Gómez
# email                                 user4@example.com
# password                                          pass4
# tokens                                              NaN
# createdAt                                    2022-01-01
# updatedAt                                    2022-01-01
# __v                                                   0
# confirmed                                           Yes
# company                                       Colegio B
# position                        Diseñador Instruccional
# phone_prefx                                          34
# phone_number                                  642871128
# address                                      Calle A 19
# zip_code                                        20117.0
# city                                          Barcelona
# country                                          España
# user_type                                     Assistant
# url_linkedin              https://linkedin.com/in/user4
# allergies                                            []
# interests             ['Negocios', 'Marketing Digital']
# food_preferences                                 vegano
# job_title                                           NaN
# eventsId                                            NaN
# completed                                           NaN
# speaker_events                                      NaN
# ids_meetings                                        NaN
# id_supplier                                         NaN
# ids_meetings_atendee                                NaN
# avatar_url                                          NaN
#
#                                                  1    \
# _id                                               22
# name                                            Jose
# surname                                      Sánchez
# email                             user22@example.com
# password                                      pass22
# tokens                                           NaN
# createdAt                                 2022-01-01
# updatedAt                                 2022-01-01
# __v                                                0
# confirmed                                        Yes
# company                       Creadores de Contenido
# position                  Investigador en E-learning
# phone_prefx                                       34
# phone_number                               663101828
# address                                  Calle B 177
# zip_code                                     12124.0
# city                                        Zaragoza
# country                                       España
# user_type                                  Assistant
# url_linkedin          https://linkedin.com/in/user22
# allergies                                    ['Sal']
# interests               ['Emprendimiento', 'Diseño']
# food_preferences                              vegano
# job_title                                        NaN
# eventsId                                         NaN
# completed                                        NaN
# speaker_events                                   NaN
# ids_meetings                                     NaN
# id_supplier                                      NaN
# ids_meetings_atendee                             NaN
# avatar_url                                       NaN
#
#                                                       2    \
# _id                                                    12
# name                                                 Luis
# surname                                             López
# email                                  user12@example.com
# password                                           pass12
# tokens                                                NaN
# createdAt                                      2022-01-01
# updatedAt                                      2022-01-01
# __v                                                     0
# confirmed                                             Yes
# company                                         Colegio B
# position                     Analista de Datos Educativos
# phone_prefx                                            34
# phone_number                                    687775487
# address                                       Calle J 124
# zip_code                                          69703.0
# city                                             Valencia
# country                                            España
# user_type                                       Assistant
# url_linkedin               https://linkedin.com/in/user12
# allergies                                              []
# interests             ['Agile', 'Educación', 'Formación']
# food_preferences                                 omnivoro
# job_title                                             NaN
# eventsId                                              NaN
# completed                                             NaN
# speaker_events                                        NaN
# ids_meetings                                          NaN
# id_supplier                                           NaN
# ids_meetings_atendee                                  NaN
# avatar_url                                            NaN
#
#                                                  3    \
# _id                                               57
# name                                           Laura
# surname                                    Fernández
# email                             user57@example.com
# password                                      pass57
# tokens                                           NaN
# createdAt                                 2022-01-01
# updatedAt                                 2022-01-01
# __v                                                0
# confirmed                                        Yes
# company                                Universidad A
# position                 Desarrollador de E-learning
# phone_prefx                                       34
# phone_number                               644114022
# address                                  Calle D 117
# zip_code                                     89133.0
# city                                        Valencia
# country                                       España
# user_type                                  Assistant
# url_linkedin          https://linkedin.com/in/user57
# allergies                                   ['Apio']
# interests                              ['Formación']
# food_preferences                              vegano
# job_title                                        NaN
# eventsId                                         NaN
# completed                                        NaN
# speaker_events                                   NaN
# ids_meetings                                     NaN
# id_supplier                                      NaN
# ids_meetings_atendee                             NaN
# avatar_url                                       NaN
#
#                                                               4    \
# _id                                                            11
# name                                                       Isabel
# surname                                                     Pérez
# email                                          user11@example.com
# password                                                   pass11
# tokens                                                        NaN
# createdAt                                              2022-01-01
# updatedAt                                              2022-01-01
# __v                                                             0
# confirmed                                                     Yes
# company                                             Universidad A
# position                                    Director de Formación
# phone_prefx                                                    34
# phone_number                                            622048295
# address                                               Calle H 141
# zip_code                                                  43288.0
# city                                                      Sevilla
# country                                                    España
# user_type                                               Assistant
# url_linkedin                       https://linkedin.com/in/user11
# allergies                                              ['Sésamo']
# interests             ['Softskills', 'Creatividad', 'Tecnología']
# food_preferences                                           vegano
# job_title                                                     NaN
# eventsId                                                      NaN
# completed                                                     NaN
# speaker_events                                                NaN
# ids_meetings                                                  NaN
# id_supplier                                                   NaN
# ids_meetings_atendee                                          NaN
# avatar_url                                                    NaN
#
#                                                 5    \
# _id                                               3
# name                                          Maria
# surname                                       Pérez
# email                             user3@example.com
# password                                      pass3
# tokens                                          NaN
# createdAt                                2022-01-01
# updatedAt                                2022-01-01
# __v                                               0
# confirmed                                       Yes
# company                                   Colegio B
# position                     Responsable de Calidad
# phone_prefx                                      34
# phone_number                              602716833
# address                                 Calle J 195
# zip_code                                    89142.0
# city                                       Valencia
# country                                      España
# user_type                                 Assistant
# url_linkedin          https://linkedin.com/in/user3
# allergies                              ['Moluscos']
# interests                              ['Negocios']
# food_preferences                        vegetariano
# job_title                                       NaN
# eventsId                                        NaN
# completed                                       NaN
# speaker_events                                  NaN
# ids_meetings                                    NaN
# id_supplier                                     NaN
# ids_meetings_atendee                            NaN
# avatar_url                                      NaN
#
#                                                                     6    \
# _id                                                                  13
# name                                                               Luis
# surname                                                           Gómez
# email                                                user13@example.com
# password                                                         pass13
# tokens                                                              NaN
# createdAt                                                    2022-01-01
# updatedAt                                                    2022-01-01
# __v                                                                   0
# confirmed                                                           Yes
# company                                                       Colegio B
# position                                        Facilitador de Talleres
# phone_prefx                                                          34
# phone_number                                                  634072365
# address                                                     Calle A 166
# zip_code                                                        37418.0
# city                                                             Madrid
# country                                                          España
# user_type                                                     Assistant
# url_linkedin                             https://linkedin.com/in/user13
# allergies                                                      ['Apio']
# interests             ['Formación', 'Emprendimiento', 'Tecnología', ...
# food_preferences                                               omnivoro
# job_title                                                           NaN
# eventsId                                                            NaN
# completed                                                           NaN
# speaker_events                                                      NaN
# ids_meetings                                                        NaN
# id_supplier                                                         NaN
# ids_meetings_atendee                                                NaN
# avatar_url                                                          NaN
#
#                                                           7    \
# _id                                                        41
# name                                                   Isabel
# surname                                                 Gómez
# email                                      user41@example.com
# password                                               pass41
# tokens                                                    NaN
# createdAt                                          2022-01-01
# updatedAt                                          2022-01-01
# __v                                                         0
# confirmed                                                 Yes
# company                                             Escuela C
# position                                  Gestor de Comunidad
# phone_prefx                                                34
# phone_number                                        656591718
# address                                           Calle E 100
# zip_code                                              15407.0
# city                                                  Sevilla
# country                                                España
# user_type                                           Assistant
# url_linkedin                   https://linkedin.com/in/user41
# allergies                              ['Moluscos', 'Sésamo']
# interests             ['Emprendimiento', 'Salud y Bienestar']
# food_preferences                                  vegetariano
# job_title                                                 NaN
# eventsId                                                  NaN
# completed                                                 NaN
# speaker_events                                            NaN
# ids_meetings                                              NaN
# id_supplier                                               NaN
# ids_meetings_atendee                                      NaN
# avatar_url                                                NaN
#
#                                                                     8    \
# _id                                                                  64
# name                                                               Jose
# surname                                                           Pérez
# email                                                user64@example.com
# password                                                         pass64
# tokens                                                              NaN
# createdAt                                                    2022-01-01
# updatedAt                                                    2022-01-01
# __v                                                                   0
# confirmed                                                           Yes
# company                                                   Universidad A
# position                                    Administrador de Plataforma
# phone_prefx                                                          34
# phone_number                                                  665854378
# address                                                     Calle D 122
# zip_code                                                        12017.0
# city                                                            Sevilla
# country                                                          España
# user_type                                                     Assistant
# url_linkedin                             https://linkedin.com/in/user64
# allergies                                    ['Frutos secos', 'Azucar']
# interests             ['Educación', 'Softskills', 'Agile', 'Creativi...
# food_preferences                                            vegetariano
# job_title                                                           NaN
# eventsId                                                            NaN
# completed                                                           NaN
# speaker_events                                                      NaN
# ids_meetings                                                        NaN
# id_supplier                                                         NaN
# ids_meetings_atendee                                                NaN
# avatar_url                                                          NaN
#
#                                                                     9    ...  \
# _id                                                                  58  ...
# name                                                                Ana  ...
# surname                                                          García  ...
# email                                                user58@example.com  ...
# password                                                         pass58  ...
# tokens                                                              NaN  ...
# createdAt                                                    2022-01-01  ...
# updatedAt                                                    2022-01-01  ...
# __v                                                                   0  ...
# confirmed                                                           Yes  ...
# company                                                   Universidad A  ...
# position                                         Director de Tecnología  ...
# phone_prefx                                                          34  ...
# phone_number                                                  641441944  ...
# address                                                      Calle E 96  ...
# zip_code                                                        35128.0  ...
# city                                                          Barcelona  ...
# country                                                          España  ...
# user_type                                                     Assistant  ...
# url_linkedin                             https://linkedin.com/in/user58  ...
# allergies                                 ['Apio', 'Sésamo', 'Mostaza']  ...
# interests             ['Creatividad', 'Salud y Bienestar', 'Gestión ...  ...
# food_preferences                                            vegetariano  ...
# job_title                                                           NaN  ...
# eventsId                                                            NaN  ...
# completed                                                           NaN  ...
# speaker_events                                                      NaN  ...
# ids_meetings                                                        NaN  ...
# id_supplier                                                         NaN  ...
# ids_meetings_atendee                                                NaN  ...
# avatar_url                                                          NaN  ...
#
#                                                                     162  \
# _id                                            667c2127a931bb6fec4f602e
# name                                                              zoom0
# surname                                                           zoom0
# email                                                 tuki4@example.com
# password              $2b$10$9kydSVwjxFoIYjAzZicYuO60AtFEQrAVmzHWP6Y...
# tokens                                                               []
# createdAt                                    2024-06-26 14:09:43.670000
# updatedAt                                    2024-06-26 14:09:43.670000
# __v                                                                   0
# confirmed                                                         False
# company                                                            zoom
# position                                                            NaN
# phone_prefx                                                         NaN
# phone_number                                                        NaN
# address                                                             NaN
# zip_code                                                            NaN
# city                                                                NaN
# country                                                             NaN
# user_type                                                      supplier
# url_linkedin                                                        NaN
# allergies                                                            []
# interests                                                            []
# food_preferences                                                     []
# job_title                                                            []
# eventsId                                                            NaN
# completed                                                         False
# speaker_events                                                       []
# ids_meetings                                                         []
# id_supplier                                    667c2127a931bb6fec4f6028
# ids_meetings_atendee                                                 []
# avatar_url                                                          NaN
#
#                                                                     163  \
# _id                                            667c214ca931bb6fec4f6034
# name                                                              zoom2
# surname                                                           zoom2
# email                                             ladrillito5@gmail.com
# password              $2b$10$OhQzok/4Jq2uMkFujihTsevEdaBmp83wcUzadvd...
# tokens                                                               []
# createdAt                                    2024-06-26 14:10:20.185000
# updatedAt                                    2024-06-26 14:10:20.185000
# __v                                                                   0
# confirmed                                                         False
# company                                                            zoom
# position                                                            NaN
# phone_prefx                                                         NaN
# phone_number                                                        NaN
# address                                                             NaN
# zip_code                                                            NaN
# city                                                                NaN
# country                                                             NaN
# user_type                                                      supplier
# url_linkedin                                                        NaN
# allergies                                                            []
# interests                                                            []
# food_preferences                                                     []
# job_title                                                            []
# eventsId                                                            NaN
# completed                                                         False
# speaker_events                                                       []
# ids_meetings                                                         []
# id_supplier                                    667c214ba931bb6fec4f6032
# ids_meetings_atendee                                                 []
# avatar_url                                                          NaN
#
#                                                                     164  \
# _id                                            667c214ca931bb6fec4f6036
# name                                                              zoom1
# surname                                                           zoom1
# email                                              paquito5@example.com
# password              $2b$10$GTgxj10G2oGVthxTFSShROuFe8lMMpOUDXGCKEl...
# tokens                                                               []
# createdAt                                    2024-06-26 14:10:20.187000
# updatedAt                                    2024-06-26 14:10:20.187000
# __v                                                                   0
# confirmed                                                         False
# company                                                            zoom
# position                                                            NaN
# phone_prefx                                                         NaN
# phone_number                                                        NaN
# address                                                             NaN
# zip_code                                                            NaN
# city                                                                NaN
# country                                                             NaN
# user_type                                                      supplier
# url_linkedin                                                        NaN
# allergies                                                            []
# interests                                                            []
# food_preferences                                                     []
# job_title                                                            []
# eventsId                                                            NaN
# completed                                                         False
# speaker_events                                                       []
# ids_meetings                                                         []
# id_supplier                                    667c214ba931bb6fec4f6032
# ids_meetings_atendee                                                 []
# avatar_url                                                          NaN
#
#                                                                     165  \
# _id                                            667c214ca931bb6fec4f6038
# name                                                              zoom0
# surname                                                           zoom0
# email                                                 tuki5@example.com
# password              $2b$10$cAEppxonESKosRjYPhzcJOWVHt231x5V3NhdBZf...
# tokens                                                               []
# createdAt                                    2024-06-26 14:10:20.188000
# updatedAt                                    2024-06-26 14:10:20.188000
# __v                                                                   0
# confirmed                                                         False
# company                                                            zoom
# position                                                            NaN
# phone_prefx                                                         NaN
# phone_number                                                        NaN
# address                                                             NaN
# zip_code                                                            NaN
# city                                                                NaN
# country                                                             NaN
# user_type                                                      supplier
# url_linkedin                                                        NaN
# allergies                                                            []
# interests                                                            []
# food_preferences                                                     []
# job_title                                                            []
# eventsId                                                            NaN
# completed                                                         False
# speaker_events                                                       []
# ids_meetings                                                         []
# id_supplier                                    667c214ba931bb6fec4f6032
# ids_meetings_atendee                                                 []
# avatar_url                                                          NaN
#
#                                                                     166  \
# _id                                            667c216fa931bb6fec4f603e
# name                                                              zoom0
# surname                                                           zoom0
# email                                                 tuki6@example.com
# password              $2b$10$0cdTE6D7Kf28nE6CiDxyj.0MLgXtI/1JHgq.gxg...
# tokens                                                               []
# createdAt                                    2024-06-26 14:10:55.311000
# updatedAt                                    2024-06-26 14:10:55.311000
# __v                                                                   0
# confirmed                                                         False
# company                                                            zoom
# position                                                            NaN
# phone_prefx                                                         NaN
# phone_number                                                        NaN
# address                                                             NaN
# zip_code                                                            NaN
# city                                                                NaN
# country                                                             NaN
# user_type                                                      supplier
# url_linkedin                                                        NaN
# allergies                                                            []
# interests                                                            []
# food_preferences                                                     []
# job_title                                                            []
# eventsId                                                            NaN
# completed                                                         False
# speaker_events                                                       []
# ids_meetings                                                         []
# id_supplier                                    667c216fa931bb6fec4f603c
# ids_meetings_atendee                                                 []
# avatar_url                                                          NaN
#
#                                                                     167  \
# _id                                            667c216fa931bb6fec4f6040
# name                                                              zoom1
# surname                                                           zoom1
# email                                              paquito6@example.com
# password              $2b$10$cKWan4MU94nG.D3o.Ak8OevqqxWfqIwg5H03kTg...
# tokens                                                               []
# createdAt                                    2024-06-26 14:10:55.312000
# updatedAt                                    2024-06-26 14:10:55.312000
# __v                                                                   0
# confirmed                                                         False
# company                                                            zoom
# position                                                            NaN
# phone_prefx                                                         NaN
# phone_number                                                        NaN
# address                                                             NaN
# zip_code                                                            NaN
# city                                                                NaN
# country                                                             NaN
# user_type                                                      supplier
# url_linkedin                                                        NaN
# allergies                                                            []
# interests                                                            []
# food_preferences                                                     []
# job_title                                                            []
# eventsId                                                            NaN
# completed                                                         False
# speaker_events                                                       []
# ids_meetings                                                         []
# id_supplier                                    667c216fa931bb6fec4f603c
# ids_meetings_atendee                                                 []
# avatar_url                                                          NaN
#
#                                                                     168  \
# _id                                            667c216fa931bb6fec4f6042
# name                                                              zoom2
# surname                                                           zoom2
# email                                             ladrillito6@gmail.com
# password              $2b$10$EfdKCMt7/i4m5/h54hAqy.D6o6XAc8SmM12Neg1...
# tokens                                                               []
# createdAt                                    2024-06-26 14:10:55.313000
# updatedAt                                    2024-06-26 14:10:55.313000
# __v                                                                   0
# confirmed                                                         False
# company                                                            zoom
# position                                                            NaN
# phone_prefx                                                         NaN
# phone_number                                                        NaN
# address                                                             NaN
# zip_code                                                            NaN
# city                                                                NaN
# country                                                             NaN
# user_type                                                      supplier
# url_linkedin                                                        NaN
# allergies                                                            []
# interests                                                            []
# food_preferences                                                     []
# job_title                                                            []
# eventsId                                                            NaN
# completed                                                         False
# speaker_events                                                       []
# ids_meetings                                                         []
# id_supplier                                    667c216fa931bb6fec4f603c
# ids_meetings_atendee                                                 []
# avatar_url                                                          NaN
#
#                                                                     169  \
# _id                                            667c2334bab4968508194544
# name                                                              zoom0
# surname                                                           zoom0
# email                                                 tuki7@example.com
# password              $2b$10$8aSS46hGkBKa1jUzMUrCtOrmkgCHrbHbVRIB7sW...
# tokens                                                               []
# createdAt                                    2024-06-26 14:18:28.084000
# updatedAt                                    2024-06-26 14:18:28.084000
# __v                                                                   0
# confirmed                                                         False
# company                                                            zoom
# position                                                            NaN
# phone_prefx                                                         NaN
# phone_number                                                        NaN
# address                                                             NaN
# zip_code                                                            NaN
# city                                                                NaN
# country                                                             NaN
# user_type                                                      supplier
# url_linkedin                                                        NaN
# allergies                                                            []
# interests                                                            []
# food_preferences                                                     []
# job_title                                                            []
# eventsId                                                            NaN
# completed                                                         False
# speaker_events                                                       []
# ids_meetings                                                         []
# id_supplier                                    667c2333bab4968508194542
# ids_meetings_atendee                                                 []
# avatar_url                                                          NaN
#
#                                                                     170  \
# _id                                            667c2334bab4968508194548
# name                                                              zoom2
# surname                                                           zoom2
# email                                             ladrillito7@gmail.com
# password              $2b$10$/k5nCtnCFIJtOfTDaXq7/.213LVdJFo5OSG.5OA...
# tokens                                                               []
# createdAt                                    2024-06-26 14:18:28.085000
# updatedAt                                    2024-06-26 14:18:28.085000
# __v                                                                   0
# confirmed                                                         False
# company                                                            zoom
# position                                                            NaN
# phone_prefx                                                         NaN
# phone_number                                                        NaN
# address                                                             NaN
# zip_code                                                            NaN
# city                                                                NaN
# country                                                             NaN
# user_type                                                      supplier
# url_linkedin                                                        NaN
# allergies                                                            []
# interests                                                            []
# food_preferences                                                     []
# job_title                                                            []
# eventsId                                                            NaN
# completed                                                         False
# speaker_events                                                       []
# ids_meetings                                                         []
# id_supplier                                    667c2333bab4968508194542
# ids_meetings_atendee                                                 []
# avatar_url                                                          NaN
#
#                                                                     171
# _id                                            667c2334bab4968508194546
# name                                                              zoom1
# surname                                                           zoom1
# email                                              paquito7@example.com
# password              $2b$10$p/CoQWKOo1XesfvFxhVYIuJkRlM6QZVXtQNCXOA...
# tokens                [eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQi...
# createdAt                                    2024-06-26 14:18:28.085000
# updatedAt                                    2024-06-27 08:34:43.532000
# __v                                                                   2
# confirmed                                                          True
# company                                                            zoom
# position                                                            NaN
# phone_prefx                                                         NaN
# phone_number                                                        NaN
# address                                                             NaN
# zip_code                                                            NaN
# city                                                                NaN
# country                                                             NaN
# user_type                                                      supplier
# url_linkedin                                                        NaN
# allergies                                                            []
# interests                                                            []
# food_preferences                                                     []
# job_title                                                            []
# eventsId                                                            NaN
# completed                                                         False
# speaker_events                                                       []
# ids_meetings          [667d23f33da71fe6346a386f, 667d24023da71fe6346...
# id_supplier                                    667c2333bab4968508194542
# ids_meetings_atendee                                                 []
# avatar_url                                                          NaN
#
# [31 rows x 172 columns]

# %%
dff_users["food_preferences"].value_counts()
# Out:
# food_preferences
# omnivoro       56
# vegano         47
# vegetariano    46
# []             22
# [vegano]        1
# Name: count, dtype: int64

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 58 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   _id                298 non-null    object
#  1   speaker_name       25 non-null     object
#  2   speaker_company    25 non-null     object
#  3   desc_event         28 non-null     object
#  4   id_place           30 non-null     object
#  5   date               32 non-null     object
#  6   hour               32 non-null     object
#  7   id_users           59 non-null     object
#  8   interest           25 non-null     object
#  9   speaker            3 non-null      object
#  10  interests          261 non-null    object
#  11  cancelled          3 non-null      object
#  12  createdAt          240 non-null    object
#  13  updatedAt          240 non-null    object
#  14  __v                240 non-null    float64
#  15  id_collab          6 non-null      float64
#  16  nombre_empresa     6 non-null      object
#  17  direccion_empresa  6 non-null      object
#  18  correo_empresa     6 non-null      object
#  19  telefono_empresa   6 non-null      float64
#  20  tipo_collab        6 non-null      object
#  21  CIF                25 non-null     object
#  22  company_name       38 non-null     object
#  23  password           258 non-null    object
#  24  address_contact    38 non-null     object
#  25  country            257 non-null    object
#  26  email              258 non-null    object
#  27  phone_prefx        257 non-null    object
#  28  phone_number       257 non-null    object
#  29  type_collab        38 non-null     object
#  30  tokens             95 non-null     object
#  31  cif                13 non-null     object
#  32  employes           13 non-null     float64
#  33  ids_user_supplier  12 non-null     object
#  34  name               217 non-null    object
#  35  surname            215 non-null    object
#  36  confirmed          145 non-null    object
#  37  company            219 non-null    object
#  38  position           138 non-null    object
#  39  address            217 non-null    object
#  40  zip_code           217 non-null    float64
#  41  city               217 non-null    object
#  42  user_type          220 non-null    object
#  43  url_linkedin       217 non-null    object
#  44  allergies          220 non-null    object
#  45  food_preferences   220 non-null    object
#  46  suplier            16 non-null     object
#  47  job_title          80 non-null     object
#  48  supplier           1 non-null      object
#  49  eventsId           2 non-null      object
#  50  meetingsId         2 non-null      object
#  51  completed          3 non-null      object
#  52  id_suplier         4 non-null      object
#  53  id_user_suplier    4 non-null      object
#  54  cancel             4 non-null      object
#  55  id_user            1 non-null      object
#  56  place_name         2 non-null      object
#  57  capacity           2 non-null      float64
# dtypes: float64(6), object(52)
# memory usage: 135.2+ KB

# %%
from pymongo import MongoClient
# import pandas as pd

# Definir la función para descargar la colección desde MongoDB
def download_collection_from_mongodb(uri, db_name, collection_name):
    # Conectar a MongoDB
    client = MongoClient(uri)
    try:
        # Seleccionar la base de datos y la colección
        db = client[db_name]
        collection = db[collection_name]

        # Descargar los datos de la colección
        data = list(collection.find())

        # Convertir los datos a un DataFrame de pandas
        df = pd.DataFrame(data)
    finally:
        # Cerrar la conexión
        client.close()
    
    return df

# Datos de conexión a MongoDB
uri = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"  # Cambia la URL según sea necesario
db_name = "Samoo"  # Cambia 'nombre_de_la_base_de_datos' por el nombre de tu base de datos
collection_name = "users"  # Cambia 'nombre_de_la_coleccion' por el nombre de tu colección

# Descargar la colección y convertirla en un DataFrame
dff_users = download_collection_from_mongodb(uri, db_name, collection_name)

# Mostrar el DataFrame
# dff_users

co = cohere.Client(api_key="***********")
question = "cuantos asistentes omnivoros hay?"
prompt = f"""En base al siguiente Dataframe {dff_users}, quiero que respondas a la pregunta registrada en {question}. En la respuesta,
 intenta ser los más conciso posible, y pon solo texto normal, nada parecido a "\n" o similar.Al revisar la información del Dataframe, necesito 
  que lo revises entero, contando cada celda para asegurarte de darme la respuesta correcta. Por ejemplo; hay 99 veganos, pero sigues dándome
  como respuesta que hay 5, eso es erroneo. """
respuesta = co.generate(
        model="xlarge",
        prompt=prompt,
        max_tokens=50
    ).generations[0].text.strip()

nav = response.generations[0].text
nav
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[9], line 41
#      36 question = "cuantos asistentes omnivoros hay?"
#      37 prompt = f"""En base al siguiente Dataframe {dff_users}, quiero que respondas a la pregunta registrada en {question}. En la respuesta,
#      38  intenta ser los más conciso posible, y pon solo texto normal, nada parecido a "\n" o similar.Al revisar la información del Dataframe, necesito
#      39   que lo revises entero, contando cada celda para asegurarte de darme la respuesta correcta. Por ejemplo; hay 99 veganos, pero sigues dándome
#      40   como respuesta que hay 5, eso es erroneo. """
# ---> 41 respuesta = co.generate(
#      42         model="xlarge",
#      43         prompt=prompt,
#      44         max_tokens=50
#      45     ).generations[0].text.strip()
#      47 nav = response.generations[0].text
#      48 nav
#
# File c:\Users\Victor\miniconda3\envs\api_env\lib\site-packages\cohere\base_client.py:1352, in BaseCohere.generate(self, prompt, model, num_generations, max_tokens, truncate, temperature, seed, preset, end_sequences, stop_sequences, k, p, frequency_penalty, presence_penalty, return_likelihoods, raw_prompting, request_options)
#    1350 except JSONDecodeError:
#    1351     raise ApiError(status_code=_response.status_code, body=_response.text)
# -> 1352 raise ApiError(status_code=_response.status_code, body=_response_json)
#
# ApiError: status_code: 404, body: {'message': "model 'xlarge' not found, make sure the correct model ID was used and that you have access to the model."}
