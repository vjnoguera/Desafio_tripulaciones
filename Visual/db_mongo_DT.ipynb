# %%
import pandas as pd
from pymongo import MongoClient
from collections import defaultdict

# %%
# URL del repositorio de MongoDB
mongo_url = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"

# %%
df_event = pd.read_csv(r"C:\Users\Victor\Desktop\Desafío Tripulaciones\CSV\EVENT_PREFERENCES.csv")
df_event
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_event = pd.read_csv(r"C:\Users\Victor\Desktop\Desafío Tripulaciones\CSV\EVENT_PREFERENCES.csv")
#       2 df_event
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Victor\\Desktop\\Desafío Tripulaciones\\CSV\\EVENT_PREFERENCES.csv'

# %%
df_meetings = pd.read_csv(r"C:\Users\Victor\Desktop\Desafío Tripulaciones\CSV\MEETINGS.csv")
df_meetings
# Out:
#    id_meeting  id_collab  id_user       fecha   hora
# 0           1          1        2  2024-07-01  10:00
# 1           2          2        4  2024-07-02  11:00
# 2           3          3        5  2024-07-03  12:00

# %%
df_collabs = pd.read_csv(r"C:\Users\Victor\Desktop\Desafío Tripulaciones\CSV\COLLABS.csv")
df_collabs
# Out:
#    id_collab nombre_empresa direccion_empresa        correo_empresa  \
# 0          1      Empresa A      Calle F, 123  empresaA@example.com
# 1          2      Empresa B      Calle G, 456  empresaB@example.com
# 2          3      Empresa C      Calle H, 789  empresaC@example.com
#
#    telefono_empresa tipo_collab id_users
# 0         111222333  Plantinium      2,3
# 1         444555666        Gold        4
# 2         777888999      Silver        5

# %%
df_places = pd.read_csv(r"C:\Users\Victor\Desktop\Desafío Tripulaciones\CSV\PLACES.csv")
df_places
# Out:
#    id_place nombre_sala  capacidad
# 0         1      Sala A         80
# 1         2      Sala B         50

# %%
df_users = pd.read_csv(r"C:\Users\Victor\Desktop\Desafío Tripulaciones\CSV\USERS_UPDATED.csv")
df_users
# Out:
#    id_user  nombre apellidos  correo_electronico  prefijo_telefono  \
# 0        1    Juan     Pérez    juan@example.com                34
# 1        2     Ana     Gómez     ana@example.com                34
# 2        3  Carlos     López  carlos@example.com                34
# 3        4   Marta   Sánchez   marta@example.com                34
# 4        5    Luis      Díaz    luis@example.com                34
#
#    numero_telefono tipo_via  numero  codigo_postal  ciudad    pais  \
# 0        123456789    Calle     123          28001  Madrid  España
# 1        987654321    Calle     456          28002  Madrid  España
# 2        456789123    Calle     789          28003  Madrid  España
# 3        321654987    Calle     101          28004  Madrid  España
# 4        789123456    Calle     202          28005  Madrid  España
#
#   nombre_usuario contrasena tipo_usuario
# 0        juan123    pass123    visitante
# 1         ana456    pass456      ponente
# 2      carlos789    pass789       collab
# 3       marta101    pass101       collab
# 4        luis202    pass202    visitante

# %%
""" BASE DE DATOS USERS"""


# URL del repositorio de MongoDB
mongo_url = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"

# Conectar al cliente de MongoDB
client = MongoClient(mongo_url)

# Seleccionar la base de datos y la colección
db = client["Samoo"]
collection = db["users"]

# Supongamos que ya tienes un dataframe llamado df
# df = pd.read_csv("tu_archivo.csv")  # Ejemplo de cómo cargar un dataframe

# Convertir el dataframe a una lista de diccionarios
data = df_users.to_dict(orient="records")

# Insertar los datos en la colección
collection.insert_many(data)

print("Datos insertados exitosamente")

# Cerrar la conexión
client.close()
# Out:
# Datos insertados exitosamente

# %%
""" BASE DE DATOS PLACES"""


# URL del repositorio de MongoDB
mongo_url = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"

# Conectar al cliente de MongoDB
client = MongoClient(mongo_url)

# Seleccionar la base de datos y la colección
db = client["Samoo"]
collection = db["places"]

# Supongamos que ya tienes un dataframe llamado df
# df = pd.read_csv("tu_archivo.csv")  # Ejemplo de cómo cargar un dataframe

# Convertir el dataframe a una lista de diccionarios
data = df_places.to_dict(orient="records")

# Insertar los datos en la colección
collection.insert_many(data)

print("Datos insertados exitosamente")

# Cerrar la conexión
client.close()
# Out:
# Datos insertados exitosamente

# %%
""" BASE DE DATOS EVENTS"""


# URL del repositorio de MongoDB
mongo_url = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"

# Conectar al cliente de MongoDB
client = MongoClient(mongo_url)

# Seleccionar la base de datos y la colección
db = client["Samoo"]
collection = db["events"]

# Supongamos que ya tienes un dataframe llamado df
# df = pd.read_csv("tu_archivo.csv")  # Ejemplo de cómo cargar un dataframe

# Convertir el dataframe a una lista de diccionarios
data = df_event.to_dict(orient="records")

# Insertar los datos en la colección
collection.insert_many(data)

print("Datos insertados exitosamente")

# Cerrar la conexión
client.close()
# Out:
# Datos insertados exitosamente

# %%
""" BASE DE DATOS MEETINGS"""


# URL del repositorio de MongoDB
mongo_url = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"

# Conectar al cliente de MongoDB
client = MongoClient(mongo_url)

# Seleccionar la base de datos y la colección
db = client["Samoo"]
collection = db["meetings"]

# Supongamos que ya tienes un dataframe llamado df
# df = pd.read_csv("tu_archivo.csv")  # Ejemplo de cómo cargar un dataframe

# Convertir el dataframe a una lista de diccionarios
data = df_meetings.to_dict(orient="records")

# Insertar los datos en la colección
collection.insert_many(data)

print("Datos insertados exitosamente")

# Cerrar la conexión
client.close()
# Out:
# Datos insertados exitosamente

# %%
""" BASE DE DATOS COLLABS"""


# URL del repositorio de MongoDB
mongo_url = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"

# Conectar al cliente de MongoDB
client = MongoClient(mongo_url)

# Seleccionar la base de datos y la colección
db = client["Samoo"]
collection = db["collabs"]

# Supongamos que ya tienes un dataframe llamado df
# df = pd.read_csv("tu_archivo.csv")  # Ejemplo de cómo cargar un dataframe

# Convertir el dataframe a una lista de diccionarios
data = df_collabs.to_dict(orient="records")

# Insertar los datos en la colección
collection.insert_many(data)

print("Datos insertados exitosamente")

# Cerrar la conexión
client.close()
# Out:
# Datos insertados exitosamente

# %%
db = client["Samoo"]
collection = db["collabs"]
dat = list(collection.find())
dff_collabs = pd.DataFrame(dat)
dff_collabs
# Out:
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# Cell In[13], line 3
#       1 db = client["Samoo"]
#       2 collection = db["collabs"]
# ----> 3 dat = list(collection.find())
#       4 dff_collabs = pd.DataFrame(dat)
#       5 dff_collabs
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\cursor.py:1243, in Cursor.next(self)
#    1241 if self.__empty:
#    1242     raise StopIteration
# -> 1243 if len(self.__data) or self._refresh():
#    1244     return self.__data.popleft()
#    1245 else:
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\cursor.py:1160, in Cursor._refresh(self)
#    1138         raise InvalidOperation(
#    1139             "Passing a 'hint' is required when using the min/max query"
#    1140             " option to ensure the query utilizes the correct index"
#    1141         )
#    1142     q = self._query_class(
#    1143         self.__query_flags,
#    1144         self.__collection.database.name,
#    (...)
#    1158         self.__exhaust,
#    1159     )
# -> 1160     self.__send_message(q)
#    1161 elif self.__id:  # Get More
#    1162     if self.__limit:
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\cursor.py:1039, in Cursor.__send_message(self, operation)
#    1036     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1038 try:
# -> 1039     response = client._run_operation(
#    1040         operation, self._unpack_response, address=self.__address
#    1041     )
#    1042 except OperationFailure as exc:
#    1043     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1044         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\mongo_client.py:1425, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1415     operation.reset()  # Reset op in case of retry.
#    1416     return server.run_operation(
#    1417         conn,
#    1418         operation,
#    (...)
#    1422         self,
#    1423     )
# -> 1425 return self._retryable_read(
#    1426     _cmd,
#    1427     operation.read_preference,
#    1428     operation.session,
#    1429     address=address,
#    1430     retryable=isinstance(operation, message._Query),
#    1431     operation=operation.name,
#    1432 )
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\mongo_client.py:1534, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1529 # Ensure that the client supports retrying on reads and there is no session in
#    1530 # transaction, otherwise, we will not support retry behavior for this call.
#    1531 retryable = bool(
#    1532     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1533 )
# -> 1534 return self._retry_internal(
#    1535     func,
#    1536     session,
#    1537     None,
#    1538     operation,
#    1539     is_read=True,
#    1540     address=address,
#    1541     read_pref=read_pref,
#    1542     retryable=retryable,
#    1543     operation_id=operation_id,
#    1544 )
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\mongo_client.py:2477, in _ClientConnectionRetryable._read(self)
#    2472 def _read(self) -> T:
#    2473     """Wrapper method for read-type retryable client executions
#    2474
#    2475     :return: Output for func()'s call
#    2476     """
# -> 2477     self._server = self._get_server()
#    2478     assert self._read_pref is not None, "Read Preference required on read calls"
#    2479     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2480         conn,
#    2481         read_pref,
#    2482     ):
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\mongo_client.py:2433, in _ClientConnectionRetryable._get_server(self)
#    2428 def _get_server(self) -> Server:
#    2429     """Retrieves a server object based on provided object context
#    2430
#    2431     :return: Abstraction to connect to server
#    2432     """
# -> 2433     return self._client._select_server(
#    2434         self._server_selector,
#    2435         self._session,
#    2436         self._operation,
#    2437         address=self._address,
#    2438         deprioritized_servers=self._deprioritized_servers,
#    2439         operation_id=self._operation_id,
#    2440     )
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\mongo_client.py:1303, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1292 """Select a server to run an operation on this client.
#    1293
#    1294 :param server_selector: The server selector to use if the session is
#    (...)
#    1300     to a specific server, used for getMore.
#    1301 """
#    1302 try:
# -> 1303     topology = self._get_topology()
#    1304     if session and not session.in_transaction:
#    1305         session._transaction.reset()
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\mongo_client.py:1246, in MongoClient._get_topology(self)
#    1240 def _get_topology(self) -> Topology:
#    1241     """Get the internal :class:`~pymongo.topology.Topology` object.
#    1242
#    1243     If this client was created with "connect=False", calling _get_topology
#    1244     launches the connection process in the background.
#    1245     """
# -> 1246     self._topology.open()
#    1247     with self.__lock:
#    1248         self._kill_cursors_executor.open()
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\topology.py:215, in Topology.open(self)
#     212         self._session_pool.reset()
#     214 with self._lock:
# --> 215     self._ensure_opened()
#
# File c:\Users\Victor\miniconda3\envs\dt_env\lib\site-packages\pymongo\topology.py:703, in Topology._ensure_opened(self)
#     698 """Start monitors, or restart after a fork.
#     699
#     700 Hold the lock when calling this.
#     701 """
#     702 if self._closed:
# --> 703     raise InvalidOperation("Cannot use MongoClient after close")
#     705 if not self._opened:
#     706     self._opened = True
#
# InvalidOperation: Cannot use MongoClient after close

# %%
""" TABLA USERS"""

from pymongo import MongoClient
# import pandas as pd

# Definir la función para descargar la colección desde MongoDB
def download_collection_from_mongodb(uri, db_name, collection_name):
    # Conectar a MongoDB
    client = MongoClient(uri)
    try:
        # Seleccionar la base de datos y la colección
        db = client[db_name]
        collection = db[collection_name]

        # Descargar los datos de la colección
        data = list(collection.find())

        # Convertir los datos a un DataFrame de pandas
        df = pd.DataFrame(data)
    finally:
        # Cerrar la conexión
        client.close()
    
    return df

# Datos de conexión a MongoDB
uri = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"  # Cambia la URL según sea necesario
db_name = "Samoo"  # Cambia 'nombre_de_la_base_de_datos' por el nombre de tu base de datos
collection_name = "users"  # Cambia 'nombre_de_la_coleccion' por el nombre de tu colección

# Descargar la colección y convertirla en un DataFrame
dff_users = download_collection_from_mongodb(uri, db_name, collection_name)

# Mostrar el DataFrame
dff_users

# Opcional: Guardar el DataFrame en un archivo CSV
# df.to_csv('nombre_del_archivo.csv', index=False)  # Cambia 'nombre_del_archivo.csv' por el nombre deseado
# Out:
#                           _id     name  surname  \
# 0                          16    Maria  Sánchez
# 1                          38      Ana  Sánchez
# 2                          26    Maria    Gómez
# 3                          12     Luis    López
# 4                          31    Laura  Sánchez
# ..                        ...      ...      ...
# 215  6679031b6071acafa1708ba2  Apple42  Apple42
# 216  6679031b6071acafa1708ba4  Apple40  Apple40
# 217  667903396071acafa1708ba7  Apple51  Apple51
# 218  667903396071acafa1708ba9  Apple52  Apple52
# 219  667903396071acafa1708bab  Apple50  Apple50
#
#                                email  \
# 0                 user16@example.com
# 1                 user38@example.com
# 2                 user26@example.com
# 3                 user12@example.com
# 4                 user31@example.com
# ..                               ...
# 215             agustiiin5@gmail.com
# 216  paquitochocolatero5@example.com
# 217             jaimito6@example.com
# 218             agustiiin6@gmail.com
# 219  paquitochocolatero6@example.com
#
#                                               password tokens  \
# 0                                               pass16    NaN
# 1                                               pass38    NaN
# 2                                               pass26    NaN
# 3                                               pass12    NaN
# 4                                               pass31    NaN
# ..                                                 ...    ...
# 215  $2b$10$0hxdq3D3jo20BeQDcFNyr.DztbLfBvPM5n8miEu...     []
# 216  $2b$10$K/Bgnn2zO49jREm52ymkV.V/iq9YQxqVtraZSGg...     []
# 217  $2b$10$7W0ZH6FGAGXYHre81cQ.X.OpH9ZPHkQG2uTjWHv...     []
# 218  $2b$10$VvNFmZEUriZ6d9/vKV9kbucUM/H7t/Dpp6MWe3l...     []
# 219  $2b$10$LCws9EZI76zarHsv4LAHyOtFLuaePN7ZgJuFj7P...     []
#
#                       createdAt                   updatedAt  __v confirmed  \
# 0                    2022-01-01                  2022-01-01    0       Yes
# 1                    2022-01-01                  2022-01-01    0       Yes
# 2                    2022-01-01                  2022-01-01    0       Yes
# 3                    2022-01-01                  2022-01-01    0       Yes
# 4                    2022-01-01                  2022-01-01    0       Yes
# ..                          ...                         ...  ...       ...
# 215  2024-06-24 05:24:43.840000  2024-06-24 05:24:43.840000    0       NaN
# 216  2024-06-24 05:24:43.841000  2024-06-24 05:24:43.841000    0       NaN
# 217  2024-06-24 05:25:13.616000  2024-06-24 05:25:13.616000    0       NaN
# 218  2024-06-24 05:25:13.617000  2024-06-24 05:25:13.617000    0       NaN
# 219  2024-06-24 05:25:13.618000  2024-06-24 05:25:13.618000    0       NaN
#
#      ...                      url_linkedin  \
# 0    ...    https://linkedin.com/in/user16
# 1    ...    https://linkedin.com/in/user38
# 2    ...    https://linkedin.com/in/user26
# 3    ...    https://linkedin.com/in/user12
# 4    ...    https://linkedin.com/in/user31
# ..   ...                               ...
# 215  ...  www.linkedin/yourlinkdinName.com
# 216  ...  www.linkedin/yourlinkdinName.com
# 217  ...  www.linkedin/yourlinkdinName.com
# 218  ...  www.linkedin/yourlinkdinName.com
# 219  ...  www.linkedin/yourlinkdinName.com
#
#                                    allergies  \
# 0                                         []
# 1                       ['Azucar', 'Huevos']
# 2                     ['Moluscos', 'Gluten']
# 3                                         []
# 4    ['Frutos secos', 'Lácteos', 'Mariscos']
# ..                                       ...
# 215                                       []
# 216                                       []
# 217                                       []
# 218                                       []
# 219                                       []
#
#                                              interests food_preferences  \
# 0    ['Creatividad', 'Marketing Digital', 'Softskil...      vegetariano
# 1                                ['Agile', 'Negocios']           vegano
# 2                                        ['Formación']           vegano
# 3                  ['Agile', 'Educación', 'Formación']         omnivoro
# 4                   ['Salud y Bienestar', 'Formación']           vegano
# ..                                                 ...              ...
# 215                                                 []               []
# 216                                                 []               []
# 217                                                 []               []
# 218                                                 []               []
# 219                                                 []               []
#
#     suplier                      job_title supplier eventsId meetingsId  \
# 0       NaN                            NaN      NaN      NaN        NaN
# 1       NaN                            NaN      NaN      NaN        NaN
# 2       NaN                            NaN      NaN      NaN        NaN
# 3       NaN                            NaN      NaN      NaN        NaN
# 4       NaN                            NaN      NaN      NaN        NaN
# ..      ...                            ...      ...      ...        ...
# 215     NaN  [Desarrollador de Contenidos]      NaN      NaN        NaN
# 216     NaN  [Desarrollador de Contenidos]      NaN      NaN        NaN
# 217     NaN  [Desarrollador de Contenidos]      NaN      NaN        NaN
# 218     NaN  [Desarrollador de Contenidos]      NaN      NaN        NaN
# 219     NaN  [Desarrollador de Contenidos]      NaN      NaN        NaN
#
#     completed
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 215       NaN
# 216       NaN
# 217       NaN
# 218       NaN
# 219       NaN
#
# [220 rows x 29 columns]

# %%
dff_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _id                 15 non-null     object
#  1   name                5 non-null      object
#  2   email               5 non-null      object
#  3   password            5 non-null      object
#  4   tokens              5 non-null      object
#  5   createdAt           5 non-null      datetime64[ns]
#  6   updatedAt           5 non-null      datetime64[ns]
#  7   __v                 5 non-null      float64
#  8   confirmed           1 non-null      object
#  9   id_user             10 non-null     float64
#  10  nombre              10 non-null     object
#  11  apellidos           10 non-null     object
#  12  correo_electronico  10 non-null     object
#  13  prefijo_telefono    10 non-null     float64
#  14  numero_telefono     10 non-null     float64
#  15  tipo_via            10 non-null     object
#  16  numero              10 non-null     float64
#  17  codigo_postal       10 non-null     float64
#  18  ciudad              10 non-null     object
#  19  pais                10 non-null     object
#  20  nombre_usuario      10 non-null     object
#  21  contrasena          10 non-null     object
#  22  tipo_usuario        10 non-null     object
# dtypes: datetime64[ns](2), float64(6), object(15)
# memory usage: 2.8+ KB

# %%
""" TABLA COLLABS"""

from pymongo import MongoClient
# import pandas as pd

# Definir la función para descargar la colección desde MongoDB
def download_collection_from_mongodb(uri, db_name, collection_name):
    # Conectar a MongoDB
    client = MongoClient(uri)
    try:
        # Seleccionar la base de datos y la colección
        db = client[db_name]
        collection = db[collection_name]

        # Descargar los datos de la colección
        data = list(collection.find())

        # Convertir los datos a un DataFrame de pandas
        df = pd.DataFrame(data)
    finally:
        # Cerrar la conexión
        client.close()
    
    return df

# Datos de conexión a MongoDB
uri = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"  # Cambia la URL según sea necesario
db_name = "Samoo"  # Cambia 'nombre_de_la_base_de_datos' por el nombre de tu base de datos
collection_name = "collabs"  # Cambia 'nombre_de_la_coleccion' por el nombre de tu colección

# Descargar la colección y convertirla en un DataFrame
dff_collabs = download_collection_from_mongodb(uri, db_name, collection_name)

# Mostrar el Dat.inaFrame
dff_collabs.info()

# Opcional: Guardar el DataFrame en un archivo CSV
# df.to_csv('nombre_del_archivo.csv', index=False)  # Cambia 'nombre_del_archivo.csv' por el nombre deseado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   _id                3 non-null      object
#  1   id_collab          3 non-null      int64
#  2   nombre_empresa     3 non-null      object
#  3   direccion_empresa  3 non-null      object
#  4   correo_empresa     3 non-null      object
#  5   telefono_empresa   3 non-null      int64
#  6   tipo_collab        3 non-null      object
#  7   id_users           3 non-null      object
# dtypes: int64(2), object(6)
# memory usage: 320.0+ bytes

# %%
""" TABLA EVENTOS"""
from pymongo import MongoClient
# import pandas as pd

# Definir la función para descargar la colección desde MongoDB
def download_collection_from_mongodb(uri, db_name, collection_name):
    # Conectar a MongoDB
    client = MongoClient(uri)
    try:
        # Seleccionar la base de datos y la colección
        db = client[db_name]
        collection = db[collection_name]

        # Descargar los datos de la colección
        data = list(collection.find())

        # Convertir los datos a un DataFrame de pandas
        df = pd.DataFrame(data)
    finally:
        # Cerrar la conexión
        client.close()
    
    return df

# Datos de conexión a MongoDB
uri = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"  # Cambia la URL según sea necesario
db_name = "Samoo"  # Cambia 'nombre_de_la_base_de_datos' por el nombre de tu base de datos
collection_name = "events"  # Cambia 'nombre_de_la_coleccion' por el nombre de tu colección

# Descargar la colección y convertirla en un DataFrame
dff_events = download_collection_from_mongodb(uri, db_name, collection_name)

# Mostrar el Dat.inaFrame
dff_events.info()

# Opcional: Guardar el DataFrame en un archivo CSV
# df.to_csv('nombre_del_archivo.csv', index=False)  # Cambia 'nombre_del_archivo.csv' por el nombre deseado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   _id                  5 non-null      object
#  1   id_user              5 non-null      int64
#  2   alergenos            5 non-null      object
#  3   preferencias_comida  5 non-null      object
#  4   intereses            5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 328.0+ bytes

# %%
""" TABLA MEETINGS"""


# Definir la función para descargar la colección desde MongoDB
def download_collection_from_mongodb(uri, db_name, collection_name):
    # Conectar a MongoDB
    client = MongoClient(uri)
    try:
        # Seleccionar la base de datos y la colección
        db = client[db_name]
        collection = db[collection_name]

        # Descargar los datos de la colección
        data = list(collection.find())

        # Convertir los datos a un DataFrame de pandas
        df = pd.DataFrame(data)
    finally:
        # Cerrar la conexión
        client.close()
    
    return df

# Datos de conexión a MongoDB
uri = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"  # Cambia la URL según sea necesario
db_name = "Samoo"  # Cambia 'nombre_de_la_base_de_datos' por el nombre de tu base de datos
collection_name = "meetings"  # Cambia 'nombre_de_la_coleccion' por el nombre de tu colección

# Descargar la colección y convertirla en un DataFrame
dff_meetings = download_collection_from_mongodb(uri, db_name, collection_name)

# Mostrar el Dat.inaFrame
dff_meetings.info()

# Opcional: Guardar el DataFrame en un archivo CSV
# df.to_csv('nombre_del_archivo.csv', index=False)  # Cambia 'nombre_del_archivo.csv' por el nombre deseado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   _id         3 non-null      object
#  1   id_meeting  3 non-null      int64
#  2   id_collab   3 non-null      int64
#  3   id_user     3 non-null      int64
#  4   fecha       3 non-null      object
#  5   hora        3 non-null      object
# dtypes: int64(3), object(3)
# memory usage: 272.0+ bytes

# %%
""" TABLA SUPLIERS"""


# Definir la función para descargar la colección desde MongoDB
def download_collection_from_mongodb(uri, db_name, collection_name):
    # Conectar a MongoDB
    client = MongoClient(uri)
    try:
        # Seleccionar la base de datos y la colección
        db = client[db_name]
        collection = db[collection_name]

        # Descargar los datos de la colección
        data = list(collection.find())

        # Convertir los datos a un DataFrame de pandas
        df = pd.DataFrame(data)
    finally:
        # Cerrar la conexión
        client.close()
    
    return df

# Datos de conexión a MongoDB
uri = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"  # Cambia la URL según sea necesario
db_name = "Samoo"  # Cambia 'nombre_de_la_base_de_datos' por el nombre de tu base de datos
collection_name = "supliers"  # Cambia 'nombre_de_la_coleccion' por el nombre de tu colección

# Descargar la colección y convertirla en un DataFrame
dff_supliers = download_collection_from_mongodb(uri, db_name, collection_name)

# Mostrar el Dat.inaFrame
dff_supliers.info()

# Opcional: Guardar el DataFrame en un archivo CSV
# df.to_csv('nombre_del_archivo.csv', index=False)  # Cambia 'nombre_del_archivo.csv' por el nombre deseado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   _id        2 non-null      object
#  1   cif        2 non-null      object
#  2   name       2 non-null      object
#  3   password   2 non-null      object
#  4   employes   2 non-null      int64
#  5   tokens     2 non-null      object
#  6   createdAt  2 non-null      datetime64[ns]
#  7   updatedAt  2 non-null      datetime64[ns]
#  8   __v        2 non-null      int64
# dtypes: datetime64[ns](2), int64(2), object(5)
# memory usage: 272.0+ bytes

# %%
""" TABLA PLACES"""


# Definir la función para descargar la colección desde MongoDB
def download_collection_from_mongodb(uri, db_name, collection_name):
    # Conectar a MongoDB
    client = MongoClient(uri)
    try:
        # Seleccionar la base de datos y la colección
        db = client[db_name]
        collection = db[collection_name]

        # Descargar los datos de la colección
        data = list(collection.find())

        # Convertir los datos a un DataFrame de pandas
        df = pd.DataFrame(data)
    finally:
        # Cerrar la conexión
        client.close()
    
    return df

# Datos de conexión a MongoDB
uri = "mongodb+srv://Cluster78620:uuMda3E0UnvIPzdi@cluster786∫20.jcfu9lt.mongodb.net"  # Cambia la URL según sea necesario
db_name = "Samoo"  # Cambia 'nombre_de_la_base_de_datos' por el nombre de tu base de datos
collection_name = "places"  # Cambia 'nombre_de_la_coleccion' por el nombre de tu colección

# Descargar la colección y convertirla en un DataFrame
dff_places = download_collection_from_mongodb(uri, db_name, collection_name)

# Mostrar el Dat.inaFrame
dff_places.info()

# Opcional: Guardar el DataFrame en un archivo CSV
# df.to_csv('nombre_del_archivo.csv', index=False)  # Cambia 'nombre_del_archivo.csv' por el nombre deseado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   _id          4 non-null      object
#  1   id_place     4 non-null      int64
#  2   nombre_sala  4 non-null      object
#  3   capacidad    4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes
